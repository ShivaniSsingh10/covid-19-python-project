# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/latest-covid19-india-statewise-data/Latest Covid-19 India Status.csv

# %%
import pandas as pd

# %%
data = pd.read_csv(r"/kaggle/input/latest-covid19-india-statewise-data/Latest Covid-19 India Status.csv")

# %%
data
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 3                                      Assam       746159       5      738119
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 9                                        Goa       263346       3      259329
# 10                                   Gujarat      1291383       5     1280299
# ...

# %%
data.count()
# Out:
# State/UTs          36
# Total Cases        36
# Active             36
# Discharged         36
# Deaths             36
# Active Ratio       36
# Discharge Ratio    36
# Death Ratio        36
# Population         36
# dtype: int64

# %%
data.isnull().sum()
# Out:
# State/UTs          0
# Total Cases        0
# Active             0
# Discharged         0
# Deaths             0
# Active Ratio       0
# Discharge Ratio    0
# Death Ratio        0
# Population         0
# dtype: int64

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.heatmap(data.isnull())
plt.show()

# %% [markdown]
# **1) Show the number of deaths and discharged cases in each region.**

# %%
data.groupby("State/UTs").sum()
# Out:
#                                           Total Cases  Active  Discharged  \
# State/UTs
# Andaman and Nicobar                             10766       0       10637
# Andhra Pradesh                                2340676       0     2325943
# Arunachal Pradesh                               67049       0       66753
# Assam                                          746159       5      738119
# Bihar                                          855267       1      842952
# Chandigarh                                     100693       0       99508
# Chhattisgarh                                  1187695       0     1173505
# Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# Delhi                                         2040910      14     2014230
# Goa                                            263346       3      259329
# Gujarat                                       1291383       5     1280299
# ...

# %%
data.groupby("State/UTs")["Deaths"].sum().sort_values(ascending = False)
# Out:
# State/UTs
# Maharashtra                                 148558
# Kerala                                       72042
# Karnataka                                    40358
# Tamil Nadu                                   38081
# Delhi                                        26666
# Uttar Pradesh                                23712
# West Bengal                                  21555
# Punjab                                       19338
# Andhra Pradesh                               14733
# Chhattisgarh                                 14190
# Bihar                                        12314
# Gujarat                                      11079
# Madhya Pradesh                               10786
# Haryana                                      10755
# Rajasthan                                     9736
# Odisha                                        9215
# Assam                                         8035
# Uttarakhand                                   7768
# ...

# %%
data.groupby("State/UTs")["Discharged"].sum().sort_values(ascending = False)
# Out:
# State/UTs
# Maharashtra                                 8022276
# Kerala                                      6835181
# Karnataka                                   4048399
# Tamil Nadu                                  3572569
# Andhra Pradesh                              2325943
# Uttar Pradesh                               2121662
# West Bengal                                 2104592
# Delhi                                       2014230
# Odisha                                      1339135
# Rajasthan                                   1316727
# Gujarat                                     1280299
# Chhattisgarh                                1173505
# Haryana                                     1068121
# Madhya Pradesh                              1045565
# Bihar                                        842952
# Telengana                                    840313
# Punjab                                       773073
# Assam                                        738119
# ...

# %% [markdown]
# **Q2) Remove all the records where active cases are zero.**

# %%
 data[~(data.Active == 0)]
# Out:
#            State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 3              Assam       746159       5      738119    8035          0.00
# 4              Bihar       855267       1      842952   12314          0.00
# 8              Delhi      2040910      14     2014230   26666          0.00
# 9                Goa       263346       3      259329    4014          0.00
# 10           Gujarat      1291383       5     1280299   11079          0.00
# 11           Haryana      1078903      27     1068121   10755          0.00
# 12  Himachal Pradesh       322905       4      318660    4241          0.00
# 14         Jharkhand       443826       1      438491    5334          0.00
# 15         Karnataka      4088769      12     4048399   40358          0.00
# 16            Kerala      6907241      18     6835181   72042          0.00
# 20       Maharashtra      8171048     214     8022276  148558          0.00
# ...

# %%
data
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 3                                      Assam       746159       5      738119
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 9                                        Goa       263346       3      259329
# 10                                   Gujarat      1291383       5     1280299
# ...

# %% [markdown]
# **Q3) In which Region, maximum number of Death cases were recorded.**

# %%
data.groupby("State/UTs")["Deaths"].sum().sort_values(ascending = False).head(1)
# Out:
# State/UTs
# Maharashtra    148558
# Name: Deaths, dtype: int64

# %% [markdown]
# **Q4) In which Region, minimum number of Deaths cases were recorded.**

# %%
data.groupby("State/UTs")["Deaths"].sum().sort_values(ascending = True).head(1)
# Out:
# State/UTs
# Dadra and Nagar Haveli and Daman and Diu    4
# Name: Deaths, dtype: int64

# %% [markdown]
# **Q5) In which state/UTs, maximum number of Total cases were recored.***

# %%
data.groupby("State/UTs")["Total Cases"].sum().sort_values(ascending = False).head(1)
# Out:
# State/UTs
# Maharashtra    8171048
# Name: Total Cases, dtype: int64
